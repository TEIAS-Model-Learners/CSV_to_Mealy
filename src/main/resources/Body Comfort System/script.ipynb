# %%
import os
import glob
import pandas as pd

PATH_TO_BASE_PRODUCTS = "./Base Products/Product CSV Files"
PATH_TO_FEATURED_PRODUCTS = "./Featured Products/Product CSV Files"
PATH_TO_BASE_DOT_FILE = "./Base Products/Product dot Files"
PATH_TO_FEATURED_DOT_FILES = "./Featured Products/Product dot Files"

# %%
def make_dot_file(data, file_name, path_to_dot_file):
    file_content = 'digraph G {\nlabel=""\n'
    file_ending = "}"
    start_state = True
    states = list(data[0].unique())
    # declaring states
    for state in states:
        if(start_state):
            file_content += state + ' [color="red"]\n'
            start_state = False
        file_content += state + '\n'
        
    # creating transitions
    for state in states:
        file_content += state + ' [label="' + state + '"];\n'
        transitions = data[data[0] == state]
        for index, row in transitions.iterrows():
            if(type(row[3]) != str or type(row[2]) != str or type(row[1]!= str)):
                print(f'state = {state}\trow1 = {row[1]} \t row2 = {row[2]}\t row3 = {row[3]}')
            file_content += state + ' -> ' + row[3] + '[label="' + row[1] + '/' + row[2] + '"]\n'
    file_content += file_ending
    
    f = open(path_to_dot_file +'/'+ file_name +'.dot', 'w')
    f.write(file_content)
    f.close()

path = PATH_TO_FEATURED_PRODUCTS + "/*.csv"
for fname in glob.glob(path):
    data = pd.read_csv(fname, header=None, index_col=None)
    print(fname.split('/')[-1])
    make_dot_file(data, fname.split('/')[-1][:-4], PATH_TO_FEATURED_DOT_FILES)
# Out:
# LED_automatic_power_window_with_central_locking_system.csv
# state = LED_AutoPW_off	row1 = pw_auto_mv_dn 	 row2 = led_pw_dn_on	 row3 = LED_AutoPW_dn_on
# state = LED_AutoPW_off	row1 = pw_auto_mv_up 	 row2 = led_pw_up_on	 row3 = LED_AutoPW_un_on
# state = LED_AutoPW_off	row1 = cls_lock 	 row2 = -	 row3 = LED_AutoPW_up_cls_on
# state = LED_AutoPW_dn_on	row1 = pw_auto_mv_stop 	 row2 = led_pw_dn_off	 row3 = LED_AutoPW_off
# state = LED_AutoPW_un_on	row1 = pw_auto_mv_stop 	 row2 = led_pw_up_off	 row3 = LED_AutoPW_off
# state = LED_AutoPW_un_on	row1 = cls_lock 	 row2 = led_pw_cls_up_on	 row3 = LED_AutoPW_cls_switch_on
# state = LED_AutoPW_up_cls_on	row1 = pw_auto_mv_up 	 row2 = led_pw_up_on.led_pw_cls_up_on	 row3 = LED_AutoPW_cls_switch_on
# state = LED_AutoPW_cls_switch_on	row1 = cls_unlock 	 row2 = led_pw_cls_up_off	 row3 = LED_AutoPW_un_on
# state = LED_AutoPW_cls_switch_on	row1 = pw_auto_mv_stop 	 row2 = led_pw_cls_up_off.led_pw_up_off	 row3 = LED_AutoPW_off
# automatic_power_window_with_central_locking_system.csv
# state = PW_up	row1 = pw_but_dn 	 row2 = pw__auto_mv_dn	 row3 = PW_pend_auto_dn
# state = PW_up	row1 = cls_lock 	 row2 = -	 row3 = PW_cls_up
# state = PW_pend_auto_dn	row1 = cls_lock 	 row2 = pw_auto_mv_stop	 row3 = PW_cls_mv_up
# state = PW_pend_auto_dn	row1 = pw_but_up 	 row2 = pw_auto_mv_stop	 row3 = PW_pend
# state = PW_pend_auto_dn	row1 = pw_pos_dn 	 row2 = pw_auto_mv_stop	 row3 = PW_dn
# state = PW_pend_auto_dn	row1 = cls_lock 	 row2 = pw_autp_mv_stop.pw_auto_mv_up	 row3 = PW_cls_mv_up
# state = PW_pend	row1 = pw_but_dn 	 row2 = pw__auto_mv_dn	 row3 = PW_pend_auto_dn
# state = PW_pend	row1 = pw_but_up 	 row2 = pw_auto_mv_up	 row3 = PW_pend_auto_up
# state = PW_pend	row1 = cls_lock 	 row2 = pw_auto_mv_up	 row3 = PW_cls_mv_up
# state = PW_dn	row1 = bw_but_up 	 row2 = pw_auto_mv_up	 row3 = PW_pend_auto_up
# state = PW_dn	row1 = cls_lock 	 row2 = pw_auto_mv_up	 row3 = PW_cls_mv_up
# state = PW_pend_auto_up	row1 = pw_but_dn 	 row2 = pw_auto_mv_stop	 row3 = PW_pend
# state = PW_pend_auto_up	row1 = fp_on 	 row2 = pw_auto_mv_stop	 row3 = PW_fp_pend
# state = PW_pend_auto_up	row1 = cls_lock 	 row2 = -	 row3 = PW_cls_mv_up
# state = PW_pend_auto_up	row1 = pw_pos_up 	 row2 = pw_auto_mv_stop	 row3 = PW_cls_up
# state = PW_fp_pend	row1 = cls_lock 	 row2 = -	 row3 = PW_fp_cls_pend
# state = PW_fp_pend	row1 = fp_off 	 row2 = pw_auto_mv_dn	 row3 = PW_pend_auto_dn
# state = PW_fp_cls_pend	row1 = cls_unlock 	 row2 = -	 row3 = PW_fp_pend
# state = PW_cls_mv_up	row1 = cls_unlock 	 row2 = -	 row3 = PW_pend_auto_up
# state = PW_cls_mv_up	row1 = pw_pos_up 	 row2 = pw_auto_mv_stop	 row3 = PW_cls_up
# state = PW_cls_mv_up	row1 = fp_on 	 row2 = pw_auto_mv_stop	 row3 = PW_fp_cls_pend
# state = PW_cls_up	row1 = cls_unlock 	 row2 = -	 row3 = PW_up
# manual_power_window_with_centeral_locking_system.csv
# state = PW_up	row1 = pw_but_dn 	 row2 = pw_mv_dn	 row3 = PW_pend_moving_dn
# state = PW_up	row1 = cls_lock 	 row2 = -	 row3 = PW_cls_up
# state = PW_pend_moving_dn	row1 = pw_but_dn 	 row2 = pw_mv_dn	 row3 = PW_pend_moving_dn
# state = PW_pend_moving_dn	row1 = pw_but_up 	 row2 = pw_mv_up	 row3 = PW_pend_moving_up
# state = PW_pend_moving_dn	row1 = pw_pos_dn 	 row2 = -	 row3 = PW_dn
# state = PW_pend_moving_dn	row1 = cls_lock 	 row2 = -	 row3 = PW_cls_pend
# state = PW_dn	row1 = cls_lock 	 row2 = -	 row3 = PW_cls_dn
# state = PW_dn	row1 = pw_but_up 	 row2 = pw_mv_up	 row3 = PW_pend_moving_up
# state = PW_cls_dn	row1 = cls_unlock 	 row2 = -	 row3 = PW_dn
# state = PW_cls_dn	row1 = pw_but_up 	 row2 = pw_mv_up	 row3 = PW_cls_pend
# state = PW_pend_moving_up	row1 = pw_but_up 	 row2 = pw_mv_up	 row3 = PW_pend_moving_up
# state = PW_pend_moving_up	row1 = pw_but_dn 	 row2 = pw_mv_dn	 row3 = PW_pend_moving_dn
# state = PW_pend_moving_up	row1 = pw_pos_up 	 row2 = -	 row3 = PW_up
# state = PW_pend_moving_up	row1 = cls_lock 	 row2 = -	 row3 = PW_cls_pend
# state = PW_pend_moving_up	row1 = fp_on 	 row2 = -	 row3 = PW_fp_pend
# state = PW_cls_pend	row1 = pw_but_up 	 row2 = pw_mv_up	 row3 = PW_cls_pend
# state = PW_cls_pend	row1 = cls_unlock 	 row2 = -	 row3 = PW_pend_moving_up
# state = PW_cls_pend	row1 = pw_pos_up 	 row2 = -	 row3 = PW_cls_up
# state = PW_cls_pend	row1 = fp_on 	 row2 = -	 row3 = PW_fp_cls_lock
# state = PW_cls_up	row1 = cls_unlock 	 row2 = -	 row3 = PW_up
# state = PW_fp_pend	row1 = cls_lock 	 row2 = -	 row3 = PW_fp_cls_lock
# state = PW_fp_pend	row1 = fp_off 	 row2 = pw_mv_dn	 row3 = PW_pend_moving_dn
# state = PW_fp_cls_lock	row1 = cls_unlock 	 row2 = -	 row3 = PW_fp_pend
# central_locking_system_with_automatic_locking.csv
# state = CLS_unlock	row1 = key_pos_lock 	 row2 = cls_lock	 row3 = CLS_lock
# state = CLS_unlock	row1 = car_drives 	 row2 = car_locked	 row3 = car_driving_locked
# state = CLS_lock	row1 = key_pos_unlock 	 row2 = cls_unlock	 row3 = CLS_unlock
# state = car_driving_locked	row1 = door_open 	 row2 = car_unlocked	 row3 = CLS_unlock
# alarm_system_with_control_alarm_system.csv
# state = AS_activated_off	row1 = key_pos_lock 	 row2 = as_active_on	 row3 = AS_on
# state = AS_activated_off	row1 = rck_lock 	 row2 = as_active_on	 row3 = AS_on
# state = AS_activated_off	row1 = as_deactivated 	 row2 = -	 row3 = AS_deactivated
# state = AS_on	row1 = rck_unlock 	 row2 = as_active_off	 row3 = AS_activated_off
# state = AS_on	row1 = key_pos_unlock 	 row2 = as_active_off	 row3 = AS_activated_off
# state = AS_on	row1 = as_alarm_detected 	 row2 = as_alarm_on	 row3 = AS_alarm
# state = AS_alarm	row1 = time_alarm_elapsed 	 row2 = alarm_was_detected.as_alarm_off	 row3 = AS_on
# state = AS_alarm	row1 = key_pos_unlock 	 row2 = as_alarm_off.as_active_off	 row3 = AS_activated_off
# state = AS_alarm	row1 = rck_unlock 	 row2 = as_alarm_off.as_active_off	 row3 = AS_activated_off
# state = AS_deactivated	row1 = as_activated 	 row2 = -	 row3 = AS_activated_off
# alarm_system_with_control_alarm_system_and_interior_monitoring.csv
# state = AS_activated_off	row1 = key_pos_lock 	 row2 = as_active_on	 row3 = AS_on
# state = AS_activated_off	row1 = rck_lock 	 row2 = as_active_on	 row3 = AS_on
# state = AS_activated_off	row1 = as_deactivated 	 row2 = -	 row3 = AS_deactivated
# state = AS_on	row1 = rck_unlock 	 row2 = as_active_off	 row3 = AS_activated_off
# state = AS_on	row1 = key_pos_unlock 	 row2 = as_active_off	 row3 = AS_activated_off
# state = AS_on	row1 = as_alarm_detected 	 row2 = as_alarm_on	 row3 = AS_alarm
# state = AS_on	row1 = im_alarm_detected 	 row2 = im_alarm_on.as_alarm_on	 row3 = AS_alarm
# state = AS_alarm	row1 = time_alarm_elapsed 	 row2 = alarm_was_detected.as_im_alarm_off.as_alarm_off	 row3 = AS_on
# state = AS_alarm	row1 = key_pos_unlock 	 row2 = as_im_alarm_off.as_alarm_off.as_active_off	 row3 = AS_activated_off
# state = AS_alarm	row1 = rck_unlock 	 row2 = as_im_alarm_off.as_alarm_off.as_active_off	 row3 = AS_activated_off
# state = AS_deactivated	row1 = as_activated 	 row2 = -	 row3 = AS_activated_off
# central_locking_system_with_remote_control_key.csv
# state = CLS_unlock	row1 = key_pos_lock 	 row2 = cls_lock	 row3 = CLS_lock
# state = CLS_unlock	row1 = rck_lock 	 row2 = cls_lock	 row3 = CLS_lock
# state = CLS_lock	row1 = key_pos_unlock 	 row2 = cls_unlock	 row3 = CLS_unlock
# state = CLS_lock	row1 = rck_unlock 	 row2 = cls_unlock	 row3 = CLS_unlock
# remote_control_key_controller_with_control_automatic_power_window_and_safety_function.csv
# state = RCK_idle	row1 = pw_rm_up 	 row2 = pw_but_up	 row3 = RCK_idle
# state = RCK_idle	row1 = pw_rm_dn 	 row2 = pw_but_dn	 row3 = RCK_idle
# state = RCK_idle	row1 = rck_but_lock 	 row2 = rck_lock	 row3 = RCK_idle
# state = RCK_idle	row1 = rck_but_unlock 	 row2 = rck_unlock	 row3 = RCK_sf_on
# state = RCK_sf_on	row1 = rck_but_lock 	 row2 = rck_lock	 row3 = RCK_idle
# state = RCK_sf_on	row1 = time_rck_sf_elapsed 	 row2 = rck_lock	 row3 = RCK_idle
# state = RCK_sf_on	row1 = pw_rm_up 	 row2 = pw_but_up	 row3 = RCK_sf_on
# state = RCK_sf_on	row1 = door_open 	 row2 = -	 row3 = RCK_sf_unlock_idle
# state = 'RCK_sf_on"	row1 = pw_rm_dn 	 row2 = pw_but_dn	 row3 = RCK_sf_on
# state = RCK_sf_unlock_idle	row1 = pw_rm_dn 	 row2 = pw_but_dn	 row3 = RCK_sf_unlock_idle
# state = RCK_sf_unlock_idle	row1 = pw_rm_up 	 row2 = pw_but_up	 row3 = RCK_sf_unlock_idle
# state = RCK_sf_unlock_idle	row1 = rck_but_lock 	 row2 = rck_lock	 row3 = RCK_idle
# human_machine_interface_with_alarm_system_and_LED_alarm_system.csv
# state = Controller	row1 = pw_but_mv_dn 	 row2 = pw_but_dn	 row3 = Controller
# state = Controller	row1 = pw_but_mv_up 	 row2 = pw_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_up 	 row2 = em_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_dn 	 row2 = em_but_dn	 row3 = Controller
# state = Controller	row1 = em_but_mv_right 	 row2 = em_but_right	 row3 = Controller
# state = Controller	row1 = em_but_mv_left 	 row2 = em_but_left	 row3 = Controller
# state = Controller	row1 = deactivate_as 	 row2 = as_deactivated	 row3 = Controller
# state = Controller	row1 = activate_as 	 row2 = as_activated	 row3 = Controller
# state = Controller	row1 = confirm_alarm 	 row2 = as_alarm_was_confirmed	 row3 = Controller
# exterior_mirror_with_heatable_and_LED_exterior_mirror.csv
# state = EM_hor_pending	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_pos_bottom 	 row2 = em_pos_vert_bottom	 row3 = EM_bottom
# state = EM_hor_pending	row1 = em_pos_left 	 row2 = em_pos_hor_left	 row3 = EM_hor_left
# state = EM_hor_pending	row1 = em_pos_top 	 row2 = em_pos_vert_top	 row3 = EM_top
# state = EM_hor_pending	row1 = em_pos_right 	 row2 = em_pos_hor_right	 row3 = EM_hor_right
# state = EM_bottom	row1 = em_but_up 	 row2 = em_pos_vert_pend.em_mv_up	 row3 = EM_hor_pending
# state = EM_bottom	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_bottom
# state = EM_bottom	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_bottom
# state = EM_bottom	row1 = em_pos_left 	 row2 = em_pos_hor_left	 row3 = EM_bottom_left
# state = EM_bottom	row1 = em_pos_right 	 row2 = em_pos_hor_right	 row3 = EM_bottom_right
# state = EM_bottom_left	row1 = em_but_right 	 row2 = em_pos_hor_pend.em_mv_right	 row3 = EM_bottom
# state = EM_bottom_left	row1 = em_but_up 	 row2 = em_pos_vert_pend.em_mv_up	 row3 = EM_hor_left
# state = EM_hor_left	row1 = em_pos_bottom 	 row2 = em_pos_vert_bottom	 row3 = EM_bottom_left
# state = EM_hor_left	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_left
# state = EM_hor_left	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_left
# state = EM_hor_left	row1 = em_but_right 	 row2 = em_pos_hor_pend.em_mv_right	 row3 = EM_hor_pending
# state = EM_hor_left	row1 = em_pos_top 	 row2 = em_pos_vert_top	 row3 = EM_top_left
# state = EM_top_left	row1 = em_but_down 	 row2 = em_pos_vert_pend.em_mv_down	 row3 = EM_hor_left
# state = EM_top_left	row1 = em_but_right 	 row2 = em_pos_hor_pend.em_mv_right	 row3 = EM_top
# state = EM_top	row1 = em_pos_left 	 row2 = em_pos_hor_left	 row3 = EM_top_left
# state = EM_top	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_top
# state = EM_top	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_top
# state = EM_top	row1 = em_but_down 	 row2 = em_pos_vert_pend.em_mv_down	 row3 = EM_hor_pending
# state = EM_top	row1 = em_pos_right 	 row2 = em_pos_hor_right	 row3 = EM_top_right
# state = EM_top_right	row1 = em_but_left 	 row2 = em_pos_hor_pend.em_mv_left	 row3 = EM_top
# state = EM_top_right	row1 = em_but_down 	 row2 = em_pos_vert_pend.em_mv_down	 row3 = EM_hor_right
# state = EM_hor_right	row1 = em_pos_top 	 row2 = em_pos_vert_top	 row3 = EM_top_right
# state = EM_hor_right	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_right
# state = EM_hor_right	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_right
# state = EM_hor_right	row1 = em_but_left 	 row2 = em_pos_hor_pend.em_mv_left	 row3 = EM_hor_pending
# state = EM_hor_right	row1 = em_pos_bottom 	 row2 = em_pos_vert_bottom	 row3 = EM_bottom_right
# state = EM_bottom_right	row1 = em_but_up 	 row2 = em_pos_vert_pend.em_mv_up	 row3 = EM_hor_right
# state = EM_bottom_right	row1 = em_but_left 	 row2 = em_pos_hor_pend.em_mv_left	 row3 = EM_bottom
# human_machine_interface_with_alarm_system.csv
# state = Controller	row1 = pw_but_mv_dn 	 row2 = pw_but_dn	 row3 = Controller
# state = Controller	row1 = pw_but_mv_up 	 row2 = pw_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_up 	 row2 = em_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_dn 	 row2 = em_but_dn	 row3 = Controller
# state = Controller	row1 = em_but_mv_right 	 row2 = em_but_right	 row3 = Controller
# state = Controller	row1 = em_but_mv_left 	 row2 = em_but_left	 row3 = Controller
# state = Controller	row1 = deactivate_as 	 row2 = as_deactivated	 row3 = Controller
# state = Controller	row1 = activate_as 	 row2 = as_activated	 row3 = Controller
# remote_control_key_controller_with_safety_function.csv
# state = RCK_idle	row1 = rck_but_lock 	 row2 = rck_lock	 row3 = RCK_idle
# state = RCK_idle	row1 = rck_but_unlock 	 row2 = rck_unlock	 row3 = RCK_sf_on
# state = RCK_sf_on	row1 = rck_but_lock 	 row2 = rck_lock	 row3 = RCK_idle
# state = RCK_sf_on	row1 = time_rck_sf_elapsed 	 row2 = rck_lock	 row3 = RCK_idle
# state = RCK_sf_on	row1 = door_open 	 row2 = -	 row3 = RCK_sf_unlock_idle
# state = RCK_sf_unlock_idle	row1 = rck_but_lock 	 row2 = rck_lock	 row3 = RCK_idle
# remote_control_key_controller_with_control_automatic_power_window.csv
# state = RCK_idle	row1 = pw_rm_dn 	 row2 = pw_but_dn	 row3 = RCK_idle
# state = RCK_idle	row1 = rck_but_lock 	 row2 = rck_lock	 row3 = RCK_idle
# state = RCK_idle	row1 = pw_rm_up 	 row2 = pw_but_up	 row3 = RCK_idle
# state = RCK_idle	row1 = rck_but_unlock 	 row2 = rck_unlock	 row3 = RCK_idle
# human_machine_interface_with_alarm_system_and_LED_alarm_system_and_manual_power_window_and_LED_power_window.csv
# state = Controller	row1 = pw_but_mv_dn 	 row2 = pw_but_dn	 row3 = Controller
# state = Controller	row1 = pw_but_mv_up 	 row2 = pw_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_up 	 row2 = em_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_dn 	 row2 = em_but_dn	 row3 = Controller
# state = Controller	row1 = em_but_mv_right 	 row2 = em_but_right	 row3 = Controller
# state = Controller	row1 = em_but_mv_left 	 row2 = em_but_left	 row3 = Controller
# state = Controller	row1 = deactivate_as 	 row2 = as_deactivated	 row3 = Controller
# state = Controller	row1 = activate_as 	 row2 = as_activated	 row3 = Controller
# state = Controller	row1 = release_pw_but_up 	 row2 = release_pw_but	 row3 = Controller
# state = Controller	row1 = release_pw_but_dn 	 row2 = release_pw_but	 row3 = Controller
# alarm_system_with_interior_monitoring.csv
# state = AS_activated_off	row1 = key_pos_lock 	 row2 = as_active_on	 row3 = AS_on
# state = AS_activated_off	row1 = as_deactivated 	 row2 = -	 row3 = AS_deactivated
# state = AS_on	row1 = key_pos_unlock 	 row2 = as_active_off	 row3 = AS_activated_off
# state = AS_on	row1 = as_alarm_detected 	 row2 = as_alarm_on	 row3 = AS_alarm
# state = AS_alarm	row1 = key_pos_unlock 	 row2 = as_im_alarm_off.as_alarm_off.as_active_off	 row3 = AS_activated_off
# state = AS_alarm	row1 = time_alarm_elapsed 	 row2 = alarm_was_detected.as_im_alarm_off.as_alarm_off	 row3 = AS_on
# state = AS_deactivated	row1 = as_activated 	 row2 = -	 row3 = AS_activated_off
# human_machine_interface_with_manual_power_window_and_LED_power_window.csv
# state = Controller	row1 = pw_but_mv_dn 	 row2 = pw_but_dn	 row3 = Controller
# state = Controller	row1 = pw_but_mv_up 	 row2 = pw_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_up 	 row2 = em_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_dn 	 row2 = em_but_dn	 row3 = Controller
# state = Controller	row1 = em_but_mv_right 	 row2 = em_but_right	 row3 = Controller
# state = Controller	row1 = em_but_mv_left 	 row2 = em_but_left	 row3 = Controller
# state = Controller	row1 = release_pw_but_dn 	 row2 = release_pw_but	 row3 = Controller
# state = Controller	row1 = release_pw_but_up 	 row2 = release_pw_but	 row3 = Controller
# human_machine_interface_with_alarm_system_and_manual_power_window_and_LED_power_window.csv
# state = Controller	row1 = pw_but_mv_dn 	 row2 = pw_but_dn	 row3 = Controller
# state = Controller	row1 = pw_but_mv_up 	 row2 = pw_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_up 	 row2 = em_but_up	 row3 = Controller
# state = Controller	row1 = em_but_mv_dn 	 row2 = em_but_dn	 row3 = Controller
# state = Controller	row1 = em_but_mv_right 	 row2 = em_but_right	 row3 = Controller
# state = Controller	row1 = em_but_mv_left 	 row2 = em_but_left	 row3 = Controller
# state = Controller	row1 = deactivate_as 	 row2 = as_deactivated	 row3 = Controller
# state = Controller	row1 = activate_as 	 row2 = as_activated	 row3 = Controller
# state = Controller	row1 = release_pw_but_up 	 row2 = release_pw_but	 row3 = Controller
# state = Controller	row1 = release_pw_but_dn 	 row2 = release_pw_but	 row3 = Controller
# state = Controller	row1 = confirm_alarm 	 row2 = as_alarm_was_confirmed	 row3 = Controller
# central_locking_system_with_remote_control_key_and_automatic_locking.csv
# state = CLS_unlock	row1 = car_drives 	 row2 = car_locked	 row3 = car_driving_locked
# state = CLS_unlock	row1 = key_pos_lock 	 row2 = cls_lock	 row3 = CLS_lock
# state = CLS_unlock	row1 = rck_lock 	 row2 = cls_lock	 row3 = CLS_lock
# state = car_driving_locked	row1 = door_open 	 row2 = car_unlocked	 row3 = CLS_unlock
# state = CLS_lock	row1 = key_pos_unlock 	 row2 = cls_unlock	 row3 = CLS_unlock
# state = CLS_lock	row1 = rck_unlock 	 row2 = cls_unlock	 row3 = CLS_unlock
# exterior_mirror_with_heatable.csv
# state = EM_hor_pending	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_hor_pending
# state = EM_hor_pending	row1 = em_pos_bottom 	 row2 = -	 row3 = EM_bottom
# state = EM_hor_pending	row1 = em_pos_left 	 row2 = -	 row3 = EM_hor_left
# state = EM_hor_pending	row1 = em_pos_top 	 row2 = -	 row3 = EM_top
# state = EM_hor_pending	row1 = em_pos_right 	 row2 = -	 row3 = EM_hor_right
# state = EM_bottom	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_pending
# state = EM_bottom	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_bottom
# state = EM_bottom	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_bottom
# state = EM_bottom	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_bottom
# state = EM_bottom	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_bottom
# state = EM_bottom	row1 = em_pos_left 	 row2 = -	 row3 = EM_bottom_left
# state = EM_bottom	row1 = em_pos_right 	 row2 = -	 row3 = EM_bottom_right
# state = EM_bottom_left	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_bottom
# state = EM_bottom_left	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_bottom_left
# state = EM_bottom_left	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_bottom_left
# state = EM_bottom_left	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_left
# state = EM_hor_left	row1 = em_pos_bottom 	 row2 = -	 row3 = EM_bottom_left
# state = EM_hor_left	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_left
# state = EM_hor_left	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_hor_left
# state = EM_hor_left	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_left
# state = EM_hor_left	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_hor_left
# state = EM_hor_left	row1 = em_pos_top 	 row2 = -	 row3 = EM_top_left
# state = EM_hor_left	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_hor_pending
# state = EM_top_left	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_left
# state = EM_top_left	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_top_left
# state = EM_top_left	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_top_left
# state = EM_top_left	row1 = em_pos_left 	 row2 = -	 row3 = EM_top
# state = EM_top	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_top_left
# state = EM_top	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_top
# state = EM_top	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_top
# state = EM_top	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_top
# state = EM_top	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_pending
# state = EM_top	row1 = em_pos_right 	 row2 = -	 row3 = EM_top_right
# state = EM_top	row1 = em_but_right 	 row2 = em_mv_right	 row3 = EM_top
# state = EM_top_right	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_top
# state = EM_top_right	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_top_right
# state = EM_top_right	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_top_right
# state = EM_top_right	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_right
# state = EM_top_right	row1 = em_pos_top 	 row2 = -	 row3 = EM_top_right
# state = EM_hor_right	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_hor_right
# state = EM_hor_right	row1 = time_heating_elapsed" 	 row2 = heating_off	 row3 = EM_hor_right
# state = EM_hor_right	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_hor_pending
# state = EM_hor_right	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_right
# state = EM_hor_right	row1 = em_pos_bottom 	 row2 = -	 row3 = EM_bottom_right
# state = EM_hor_right	row1 = em_but_down 	 row2 = em_mv_down	 row3 = EM_hor_right
# state = EM_bottom_right	row1 = em_but_up 	 row2 = em_mv_up	 row3 = EM_hor_right
# state = EM_bottom_right	row1 = em_too_cold 	 row2 = heating_on	 row3 = EM_bottom_right
# state = EM_bottom_right	row1 = time_heating_elapsed 	 row2 = heating_off	 row3 = EM_bottom_right
# state = EM_bottom_right	row1 = em_but_left 	 row2 = em_mv_left	 row3 = EM_bottom

# %%
list(data[0].unique())
# Out:
# ['AS_alarm_detected_LED_off', 'AS_alarm_detected_LED_on']

# %%
br = 'sjkdf"'
br += 'jajaja' + '\n'
print(br)
# new_file = open("./newfile.dot", 'w')
# new_file.write(br)
# new_file.close()
# Out:
# sjkdf"jajaja

# %%
data[data[0] == 'AS_alarm_detected_LED_off']
# Out:
#                            0                      1                         2  \
# 0  AS_alarm_detected_LED_off  as_alarm_was_detected  led_as_alarm_detected_on
#
#                           3
# 0  AS_alarm_detected_LED_on

# %%
for index, row in data.iterrows():
    br += row[1]

# %%
li = [1]
print(f'somethin = {li[0]}')
# Out:
# somethin = 1
